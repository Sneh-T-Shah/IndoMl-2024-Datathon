# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/indoml-phase2/train.features
# /kaggle/input/indoml-phase2/final_test_data.features
# /kaggle/input/indoml-phase2/train.labels
# /kaggle/input/indoml-phase2/phase_2_test_set1.features

# %%
# !pip install txtai
# Out:
# Collecting txtai
#   Downloading txtai-7.5.0-py3-none-any.whl.metadata (28 kB)
# Collecting faiss-cpu>=1.7.1.post2 (from txtai)
#   Downloading faiss_cpu-1.9.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.4 kB)
# Requirement already satisfied: msgpack>=1.0.7 in /opt/conda/lib/python3.10/site-packages (from txtai) (1.0.8)
# Requirement already satisfied: torch>=1.12.1 in /opt/conda/lib/python3.10/site-packages (from txtai) (2.4.0+cpu)
# Requirement already satisfied: transformers>=4.28.0 in /opt/conda/lib/python3.10/site-packages (from txtai) (4.45.1)
# Requirement already satisfied: huggingface-hub>=0.19.0 in /opt/conda/lib/python3.10/site-packages (from txtai) (0.25.1)
# Requirement already satisfied: numpy>=1.18.4 in /opt/conda/lib/python3.10/site-packages (from txtai) (1.26.4)
# Requirement already satisfied: pyyaml>=5.3 in /opt/conda/lib/python3.10/site-packages (from txtai) (6.0.2)
# Requirement already satisfied: regex>=2022.8.17 in /opt/conda/lib/python3.10/site-packages (from txtai) (2024.5.15)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from faiss-cpu>=1.7.1.post2->txtai) (21.3)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.19.0->txtai) (3.15.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.19.0->txtai) (2024.6.1)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.19.0->txtai) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.19.0->txtai) (4.66.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.19.0->txtai) (4.12.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.12.1->txtai) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.12.1->txtai) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.12.1->txtai) (3.1.4)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.28.0->txtai) (0.4.5)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.28.0->txtai) (0.20.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->faiss-cpu>=1.7.1.post2->txtai) (3.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.12.1->txtai) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.19.0->txtai) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.19.0->txtai) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.19.0->txtai) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.19.0->txtai) (2024.8.30)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.12.1->txtai) (1.3.0)
# Downloading txtai-7.5.0-py3-none-any.whl (244 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.6/244.6 kB 5.0 MB/s eta 0:00:00a 0:00:01
# Downloading faiss_cpu-1.9.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (27.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.5/27.5 MB 43.8 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: faiss-cpu, txtai
# Successfully installed faiss-cpu-1.9.0 txtai-7.5.0

# %%
def load_data(input_file, labels_file):
    input_data = pd.read_json(input_file, lines=True)
    labels_data = pd.read_json(labels_file, lines=True)
    
#     input_data = input_data[:10000]
#     labels_data = labels_data[:10000]
    
    # Merge the input and labels data on indoml_id
    merged_data = pd.merge(input_data, labels_data, on='indoml_id', how='inner')
    
    return merged_data

df = load_data('/kaggle/input/indoml-phase2/train.features', '/kaggle/input/indoml-phase2/train.labels')

# %%
df.head()
# Out:
#    indoml_id             description      retailer  price  supergroup  \
# 0          0                1 adblue  organicorner  25.35  automotive
# 1          1           1 car mat set   greenharbor   4.99  automotive
# 2          2       1 cp rmx scrnwash      naturify   3.85  automotive
# 3          3                1 diesel        ecogro   4.41  automotive
# 4          4  1 unstoppable refrsher   greenharbor   3.00  automotive
#
#                              group      module        brand
# 0  automotive detail unknown total  automotive  receipt all
# 1  automotive detail unknown total  automotive  receipt all
# 2  automotive detail unknown total  automotive  receipt all
# 3  automotive detail unknown total  automotive  receipt all
# 4  automotive detail unknown total  automotive  receipt all

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, supergroup_train, supergroup_test, group_train, group_test, module_train, module_test, brand_train, brand_test = train_test_split(
    df['description'], df['supergroup'], df['group'], df['module'], df['brand'], test_size=0.20, random_state=42)

# %%
from txtai.embeddings import Embeddings
from tqdm import tqdm

# Initialize the embeddings model
embeddings = Embeddings({"path": "sentence-transformers/all-MiniLM-L6-v2"})
# Out:
# /opt/conda/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:1617: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be deprecated in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %%
def index_data(description):
    # Convert DataFrame into format suitable for txtai with tqdm progress bar
    documents = [(i, row, None) for i, row in tqdm(enumerate(description), total=len(description), desc="Indexing Data")]
    embeddings.index(documents)
    print("Data has been indexed successfully!")

# Function to search based on query
def search_class(query):
    # Search for the best match based on the query
    results = embeddings.search(query, 3)
    if results:
        idx = results[0][0]
        
        return df.iloc[idx]["supergroup"], df.iloc[idx]["group"], df.iloc[idx]["module"], df.iloc[idx]["brand"]
    return None

# %%
# Indexing the data
index_data(X_train)
# Out:
# Indexing Data: 100%|██████████| 449470/449470 [00:00<00:00, 933469.64it/s]
# Data has been indexed successfully!

# %%
# Search query example
query = "m pitted black olive"
result = search_class(query)

if result:
    print(f"Class found: {result}")
else:
    print("No matching class found")
# Out:
# Class found: ('home do it yourself', 'home do it yourself detail unknown total', 'home do it yourself', 'receipt all')

# %%
# # Save the embeddings to a directory
# embeddings.save("path_to_save_embeddings")

# %%
# # Load the embeddings from the saved directory
# loaded_embeddings = Embeddings()
# loaded_embeddings.load("path_to_save_embeddings")

# %%
# test_df = pd.read_json('/kaggle/input/indoml-phase2/final_test_data.features',lines=True)

# %%
# for i in range(len(test_df)):
#     result = search_class(test_df.iloc[i]['description'])
#     print(result)

# %%
# def test(test_df):
#     # Initialize lists to store predictions
#     supergroups_list = []
#     groups_list = []
#     modules_list = []
#     brands_list = []

#     length_df = test_df.shape[0]
    
#     # Iterate through each row in the DataFrame
#     for i in range(length_df):
#         if i % 100 == 0:
#             print(f"Processing {i} of {length_df - 1}")
#         # Get predictions for the current row
#         predictions = search_class(test_df.iloc[i]['description'])
        
#         # Append predictions to respective lists
#         supergroups_list.append(predictions[0])
#         groups_list.append(predictions[1])
#         modules_list.append(predictions[2])
#         brands_list.append(predictions[3])

#     # Add predictions as new columns to the DataFrame
#     test_df['supergroup'] = supergroups_list
#     test_df['group'] = groups_list
#     test_df['module'] = modules_list
#     test_df['brand'] = brands_list
    
#     # Drop unnecessary columns
#     test_df.drop(columns=['description', 'retailer', 'price'], inplace=True)
    
#     # Save the modified DataFrame to a JSON file
#     test_df.to_json('predictions.predict', orient='records', lines=True)
    
#     print("Predictions saved to the predictions.predict file!")

# %%
# test(test_df)

# %%
def test(X_test, supergroup_test, group_test, module_test, brand_test):
    # Initialize lists to store predictions
    supergroups_list = []
    groups_list = []
    modules_list = []
    brands_list = []

    length_df = X_test.shape[0]
    
    # Iterate through each row in the Series
    for i in range(length_df):
        if i % 100 == 0:
            print(f"Processing {i} of {length_df - 1}")
        # Get predictions for the current description
        predictions = search_class(X_test.iloc[i])  # Access directly as it's a Series
        
        # Append predictions to respective lists
        supergroups_list.append(predictions[0])
        groups_list.append(predictions[1])
        modules_list.append(predictions[2])
        brands_list.append(predictions[3])

    # Convert lists to pandas Series for easy comparison with the test sets
    supergroup_pred = pd.Series(supergroups_list)
    group_pred = pd.Series(groups_list)
    module_pred = pd.Series(modules_list)
    brand_pred = pd.Series(brands_list)

    # Reset index to ensure comparison works
    supergroup_test = supergroup_test.reset_index(drop=True)
    group_test = group_test.reset_index(drop=True)
    module_test = module_test.reset_index(drop=True)
    brand_test = brand_test.reset_index(drop=True)

    # Calculate individual accuracies
    supergroup_accuracy = accuracy_score(supergroup_test, supergroup_pred)
    group_accuracy = accuracy_score(group_test, group_pred)
    module_accuracy = accuracy_score(module_test, module_pred)
    brand_accuracy = accuracy_score(brand_test, brand_pred)

    # Calculate item accuracy (all four must be correct)
    item_accuracy = accuracy_score(
        (supergroup_test == supergroup_pred) & 
        (group_test == group_pred) & 
        (module_test == module_pred) & 
        (brand_test == brand_pred), 
        [True] * len(supergroup_test)
    )

    # Calculate F1 scores for each class
    supergroup_f1 = f1_score(supergroup_test, supergroup_pred, average='weighted')
    group_f1 = f1_score(group_test, group_pred, average='weighted')
    module_f1 = f1_score(module_test, module_pred, average='weighted')
    brand_f1 = f1_score(brand_test, brand_pred, average='weighted')

    # Print accuracies and F1 scores
    print(f"Supergroup Accuracy: {supergroup_accuracy:.4f}, F1 Score: {supergroup_f1:.4f}")
    print(f"Group Accuracy: {group_accuracy:.4f}, F1 Score: {group_f1:.4f}")
    print(f"Module Accuracy: {module_accuracy:.4f}, F1 Score: {module_f1:.4f}")
    print(f"Brand Accuracy: {brand_accuracy:.4f}, F1 Score: {brand_f1:.4f}")
    print(f"Item Accuracy (all 4 correct): {item_accuracy:.4f}")

    # Save predictions to a DataFrame for output
    predictions_df = pd.DataFrame({
        'supergroup': supergroups_list,
        'group': groups_list,
        'module': modules_list,
        'brand': brands_list
    })
    
    # Concatenate with X_test for saving to JSON, if needed
    output_df = pd.concat([X_test.reset_index(drop=True), predictions_df], axis=1)

    # Save the modified DataFrame to a JSON file
    output_df.to_json('predictions.predict', orient='records', lines=True)
    
    print("Predictions saved to the predictions.predict file!")

# %%
test(X_test, supergroup_test, group_test, module_test, brand_test)
# Out:
# Processing 0 of 112367
# Processing 100 of 112367
# Processing 200 of 112367
# Processing 300 of 112367
# Processing 400 of 112367
# Processing 500 of 112367
# Processing 600 of 112367
# Processing 700 of 112367
# Processing 800 of 112367
# Processing 900 of 112367
# Processing 1000 of 112367
# Processing 1100 of 112367
# Processing 1200 of 112367
# Processing 1300 of 112367
# Processing 1400 of 112367
# Processing 1500 of 112367
# Processing 1600 of 112367
# Processing 1700 of 112367
# Processing 1800 of 112367
# Processing 1900 of 112367
# Processing 2000 of 112367
# Processing 2100 of 112367
# Processing 2200 of 112367
# Processing 2300 of 112367
# Processing 2400 of 112367
# Processing 2500 of 112367
# Processing 2600 of 112367
# Processing 2700 of 112367
# Processing 2800 of 112367
# Processing 2900 of 112367
# Processing 3000 of 112367
# Processing 3100 of 112367
# Processing 3200 of 112367
# Processing 3300 of 112367
# Processing 3400 of 112367
# Processing 3500 of 112367
# Processing 3600 of 112367
# Processing 3700 of 112367
# Processing 3800 of 112367
# Processing 3900 of 112367
# Processing 4000 of 112367
# Processing 4100 of 112367
# Processing 4200 of 112367
# Processing 4300 of 112367
# Processing 4400 of 112367
# Processing 4500 of 112367
# Processing 4600 of 112367
# Processing 4700 of 112367
# Processing 4800 of 112367
# Processing 4900 of 112367
# Processing 5000 of 112367
# Processing 5100 of 112367
# Processing 5200 of 112367
# Processing 5300 of 112367
# Processing 5400 of 112367
# Processing 5500 of 112367
# Processing 5600 of 112367
# Processing 5700 of 112367
# Processing 5800 of 112367
# Processing 5900 of 112367
# Processing 6000 of 112367
# Processing 6100 of 112367
# Processing 6200 of 112367
# Processing 6300 of 112367
# Processing 78900 of 112367
# Processing 79000 of 112367
# Processing 79100 of 112367
# Processing 79200 of 112367
# Processing 79300 of 112367
# Processing 79400 of 112367
# Processing 79500 of 112367
# Processing 79600 of 112367
# Processing 79700 of 112367
# Processing 79800 of 112367
# Processing 79900 of 112367
# Processing 80000 of 112367
# Processing 80100 of 112367
# Processing 80200 of 112367
# Processing 80300 of 112367
# Processing 80400 of 112367
# Processing 80500 of 112367
# Processing 80600 of 112367
# Processing 80700 of 112367
# Processing 80800 of 112367
# Processing 80900 of 112367
# Processing 81000 of 112367
# Processing 81100 of 112367
# Processing 81200 of 112367
# Processing 81300 of 112367
# Processing 81400 of 112367
# Processing 81500 of 112367
# Processing 81600 of 112367
# Processing 81700 of 112367
# Processing 81800 of 112367
# Processing 81900 of 112367
# Processing 82000 of 112367
# Processing 82100 of 112367
# Processing 82200 of 112367
# Processing 82300 of 112367
# Processing 82400 of 112367
# Processing 82500 of 112367
# Processing 82600 of 112367
# Processing 82700 of 112367
# Processing 82800 of 112367
# Processing 82900 of 112367
# Processing 83000 of 112367
# Processing 83100 of 112367
# Processing 83200 of 112367
# Processing 83300 of 112367
# Processing 83400 of 112367
# Processing 83500 of 112367
# Processing 83600 of 112367
# Processing 83700 of 112367
# Processing 83800 of 112367
# Processing 83900 of 112367
# Processing 84000 of 112367
# Processing 84100 of 112367
# Processing 84200 of 112367
# Processing 84300 of 112367
# Processing 84400 of 112367
# Processing 84500 of 112367
# Processing 84600 of 112367
# Processing 84700 of 112367
# Processing 84800 of 112367
# Processing 84900 of 112367
# Processing 85000 of 112367
# Processing 85100 of 112367
# Processing 85200 of 112367
# Processing 85300 of 112367
# Processing 85400 of 112367
# Processing 85500 of 112367
# Processing 85600 of 112367
# Processing 85700 of 112367
# Processing 85800 of 112367
# Processing 85900 of 112367
# Processing 86000 of 112367
# Processing 86100 of 112367
# Processing 86200 of 112367
# Processing 86300 of 112367
# Processing 86400 of 112367
# Processing 86500 of 112367
# Processing 86600 of 112367
# Processing 86700 of 112367
# Processing 86800 of 112367
# Processing 86900 of 112367
# Processing 87000 of 112367
# Processing 87100 of 112367
# Processing 87200 of 112367
# Processing 87300 of 112367
# Processing 87400 of 112367
# Processing 87500 of 112367
# Processing 87600 of 112367
# Processing 87700 of 112367
# Processing 87800 of 112367
# Processing 87900 of 112367
# Processing 88000 of 112367
# Processing 88100 of 112367
# Processing 88200 of 112367
# Processing 88300 of 112367
# Processing 88400 of 112367
# Processing 88500 of 112367
# Processing 88600 of 112367
# Processing 88700 of 112367
# Processing 88800 of 112367
# Processing 88900 of 112367
# Processing 89000 of 112367
# Processing 89100 of 112367
# Processing 89200 of 112367
# Processing 89300 of 112367
# Processing 89400 of 112367
# Processing 89500 of 112367
# Processing 89600 of 112367
# Processing 89700 of 112367
# Processing 89800 of 112367
# Processing 89900 of 112367
# Processing 90000 of 112367
# Processing 90100 of 112367
# Processing 90200 of 112367
# Processing 90300 of 112367
# Processing 90400 of 112367
# Processing 90500 of 112367
# Processing 90600 of 112367
# Processing 90700 of 112367
# Processing 90800 of 112367
# Processing 90900 of 112367
# Processing 103100 of 112367
# Processing 103200 of 112367
# Processing 103300 of 112367
# Processing 103400 of 112367
# Processing 103500 of 112367
# Processing 103600 of 112367
# Processing 103700 of 112367
# Processing 103800 of 112367
# Processing 103900 of 112367
# Processing 104000 of 112367
# Processing 104100 of 112367
# Processing 104200 of 112367
# Processing 104300 of 112367
# Processing 104400 of 112367
# Processing 104500 of 112367
# Processing 104600 of 112367
# Processing 104700 of 112367
# Processing 104800 of 112367
# Processing 104900 of 112367
# Processing 105000 of 112367
# Processing 105100 of 112367
# Processing 105200 of 112367
# Processing 105300 of 112367
# Processing 105400 of 112367
# Processing 105500 of 112367
# Processing 105600 of 112367
# Processing 105700 of 112367
# Processing 105800 of 112367
# Processing 105900 of 112367
# Processing 106000 of 112367
# Processing 106100 of 112367
# Processing 106200 of 112367
# Processing 106300 of 112367
# Processing 106400 of 112367
# Processing 106500 of 112367
# Processing 106600 of 112367
# Processing 106700 of 112367
# Processing 106800 of 112367
# Processing 106900 of 112367
# Processing 107000 of 112367
# Processing 107100 of 112367
# Processing 107200 of 112367
# Processing 107300 of 112367
# Processing 107400 of 112367
# Processing 107500 of 112367
# Processing 107600 of 112367
# Processing 107700 of 112367
# Processing 107800 of 112367
# Processing 107900 of 112367
# Processing 108000 of 112367
# Processing 108100 of 112367
# Processing 108200 of 112367
# Processing 108300 of 112367
# Processing 108400 of 112367
# Processing 108500 of 112367
# Processing 108600 of 112367
# Processing 108700 of 112367
# Processing 108800 of 112367
# Processing 108900 of 112367
# Processing 109000 of 112367
# Processing 109100 of 112367
# Processing 109200 of 112367
# Processing 109300 of 112367
# Processing 109400 of 112367
# Processing 109500 of 112367
# Processing 109600 of 112367
# Processing 109700 of 112367
# Processing 109800 of 112367
# Processing 109900 of 112367
# Processing 110000 of 112367
# Processing 110100 of 112367
# Processing 110200 of 112367
# Processing 110300 of 112367
# Processing 110400 of 112367
# Processing 110500 of 112367
# Processing 110600 of 112367
# Processing 110700 of 112367
# Processing 110800 of 112367
# Processing 110900 of 112367
# Processing 111000 of 112367
# Processing 111100 of 112367
# Processing 111200 of 112367
# Processing 111300 of 112367
# Processing 111400 of 112367
# Processing 111500 of 112367
# Processing 111600 of 112367
# Processing 111700 of 112367
# Processing 111800 of 112367
# Processing 111900 of 112367
# Processing 112000 of 112367
# Processing 112100 of 112367
# Processing 112200 of 112367
# Processing 112300 of 112367
# Supergroup Accuracy: 0.0899, F1 Score: 0.0811
# Group Accuracy: 0.0173, F1 Score: 0.0154
# Module Accuracy: 0.0133, F1 Score: 0.0118
# Brand Accuracy: 0.0640, F1 Score: 0.0681
# Item Accuracy (all 4 correct): 0.0082
# Predictions saved to the predictions.predict file!

# %%
X_test
# Out:
# 526511                        hotorsport news
# 119006    125 each growers harvest pure apple
# 247960         crispcorner chicken kormapilau
# 201914                   cp mayonnaise 1 down
# 136483                          ne pu mini sk
#                          ...
# 275020                     british thole milk
# 97787          graze cocoa vanilla bar 4 30 g
# 446207                    nutmeg cotwool buds
# 337800                        us yum yjms x 4
# 130952                    invisibob sprunchie
# Name: description, Length: 112368, dtype: object
