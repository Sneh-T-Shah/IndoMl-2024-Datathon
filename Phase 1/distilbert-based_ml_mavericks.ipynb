# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/datathon-indo-ml/attribute_train.data
# /kaggle/input/datathon-indo-ml/attribute_val.solution
# /kaggle/input/datathon-indo-ml/attribute_val.data
# /kaggle/input/datathon-indo-ml/attribute_train.solution
# /kaggle/input/datathon-indo-ml/attribute_test.data

# %%
import json
import pandas as pd

def read_json_to_dataframe(file_path):
    # Read the JSON file line by line
    with open(file_path, 'r') as file:
        data = [json.loads(line) for line in file]
    
    # Convert the list of dictionaries to a DataFrame
    df = pd.DataFrame(data)
    
    return df

# Read input data
input_file_path = '/kaggle/input/datathon-indo-ml/attribute_train.data'
input_df = read_json_to_dataframe(input_file_path)

# Read output data
output_file_path = '/kaggle/input/datathon-indo-ml/attribute_train.solution'
output_df = read_json_to_dataframe(output_file_path)

# Display the first few rows of each DataFrame
print("Input DataFrame:")
print(input_df.head())
print("\nOutput DataFrame:")
print(output_df.head())

# Check the number of rows in each DataFrame
print(f"\nNumber of rows in input DataFrame: {len(input_df)}")
print(f"Number of rows in output DataFrame: {len(output_df)}")

# Merge the input and output DataFrames on 'indoml_id'
merged_df = pd.merge(input_df, output_df, on='indoml_id', how='inner')

print("\nMerged DataFrame:")
print(merged_df.head())
print(f"\nNumber of rows in merged DataFrame: {len(merged_df)}")

# Save the merged DataFrame to a CSV file (optional)
merged_df.to_csv('merged_data.csv', index=False)
# Out:
# Input DataFrame:
#    indoml_id                                              title  \
# 0          0  Enclume Angled Pot Hook, Set of 6, Use with Po...
# 1          1       Schutt Vengeance DCT Hybrid Youth Football H
# 2          2         Easton 2014 MAKO SL14MK9 Baseball Bat (-9)
# 3          3    Bilstein B46-0929 Heavy-Duty Gas Shock Absorber
# 4          4  Apple Red Cardstock - 8.5 x 11 inch - 65Lb Cov...
#
#               store details_Manufacturer
# 0           Enclume              Enclume
# 1            Schutt               Schutt
# 2            Easton  Easton Sports, Inc.
# 3          Bilstein             Bilstein
# 4  Clear Path Paper     Clear Path Paper
#
# Output DataFrame:
#    indoml_id     details_Brand            L0_category        L1_category  \
# 0          0           Enclume         Home & Kitchen   Kitchen & Dining
# 1          1            Schutt      Sports & Outdoors             Sports
# 2          2            Easton      Sports & Outdoors             Sports
# 3          3          Bilstein             Automotive  Replacement Parts
# 4          4  Clear Path Paper  Arts, Crafts & Sewing           Crafting
#
#                    L2_category      L3_category      L4_category
# 0       Storage & Organization  Racks & Holders        Pot Racks
# 1                  Team Sports         Football  Protective Gear
# 2                  Team Sports         Baseball    Baseball Bats
# 3  Shocks, Struts & Suspension           Shocks               na
# 4         Paper & Paper Crafts            Paper       Card Stock
#
# Number of rows in input DataFrame: 443499
# Number of rows in output DataFrame: 443499
#
# Merged DataFrame:
#    indoml_id                                              title  \
# 0          0  Enclume Angled Pot Hook, Set of 6, Use with Po...
# 1          1       Schutt Vengeance DCT Hybrid Youth Football H
# 2          2         Easton 2014 MAKO SL14MK9 Baseball Bat (-9)
# 3          3    Bilstein B46-0929 Heavy-Duty Gas Shock Absorber
# 4          4  Apple Red Cardstock - 8.5 x 11 inch - 65Lb Cov...
#
#               store details_Manufacturer     details_Brand  \
# 0           Enclume              Enclume           Enclume
# 1            Schutt               Schutt            Schutt
# 2            Easton  Easton Sports, Inc.            Easton
# 3          Bilstein             Bilstein          Bilstein
# 4  Clear Path Paper     Clear Path Paper  Clear Path Paper
#
#              L0_category        L1_category                  L2_category  \
# 0         Home & Kitchen   Kitchen & Dining       Storage & Organization
# 1      Sports & Outdoors             Sports                  Team Sports
# 2      Sports & Outdoors             Sports                  Team Sports
# 3             Automotive  Replacement Parts  Shocks, Struts & Suspension
# 4  Arts, Crafts & Sewing           Crafting         Paper & Paper Crafts
#
#        L3_category      L4_category
# 0  Racks & Holders        Pot Racks
# 1         Football  Protective Gear
# 2         Baseball    Baseball Bats
# 3           Shocks               na
# 4            Paper       Card Stock
#
# Number of rows in merged DataFrame: 443499

# %%
merged_df
# Out:
#         indoml_id                                              title  \
# 0               0  Enclume Angled Pot Hook, Set of 6, Use with Po...
# 1               1       Schutt Vengeance DCT Hybrid Youth Football H
# 2               2         Easton 2014 MAKO SL14MK9 Baseball Bat (-9)
# 3               3    Bilstein B46-0929 Heavy-Duty Gas Shock Absorber
# 4               4  Apple Red Cardstock - 8.5 x 11 inch - 65Lb Cov...
# ...           ...                                                ...
# 443494     443494  Sony DCR-HC32 MiniDV Handycam Camcorder with 2...
# 443495     443495  Monster Truck Parking Sign Rally Owner Driver ...
# 443496     443496          3dRose Pyrenees Dog Dad Mug, 11 oz, Black
# 443497     443497                        adidas F50 Lesto Shin Guard
# 443498     443498  Kingston Digital SUV500/480G 480GB SSDNOW UV50...
#
#                    store      details_Manufacturer     details_Brand  \
# 0                Enclume                   Enclume           Enclume
# 1                 Schutt                    Schutt            Schutt
# 2                 Easton       Easton Sports, Inc.            Easton
# 3               Bilstein                  Bilstein          Bilstein
# 4       Clear Path Paper          Clear Path Paper  Clear Path Paper
# ...                  ...                       ...               ...
# 443494              Sony                      Sony              Sony
# 443495       SignMission  Mighty Skins -- Dropship       SignMission
# 443496            3dRose                     3EROS            3dRose
# 443497            adidas                    adidas            adidas
# 443498          Kingston    Kingston Digital, Inc.          Kingston
#
#                   L0_category              L1_category  \
# 0              Home & Kitchen         Kitchen & Dining
# 1           Sports & Outdoors                   Sports
# 2           Sports & Outdoors                   Sports
# 3                  Automotive        Replacement Parts
# 4       Arts, Crafts & Sewing                 Crafting
# ...                       ...                      ...
# 443494            Electronics           Camera & Photo
# 443495         Home & Kitchen       Home Dcor Products
# 443496         Home & Kitchen         Kitchen & Dining
# 443497      Sports & Outdoors                   Sports
# 443498            Electronics  Computers & Accessories
#
#                         L2_category             L3_category  \
# 0            Storage & Organization         Racks & Holders
# 1                       Team Sports                Football
# 2                       Team Sports                Baseball
# 3       Shocks, Struts & Suspension                  Shocks
# 4              Paper & Paper Crafts                   Paper
# ...                             ...                     ...
# 443494                        Video              Camcorders
# 443495            Home Dcor Accents  Decorative Accessories
# 443496        Dining & Entertaining                 Novelty
# 443497                  Team Sports                  Soccer
# 443498          Computer Components     Internal Components
#
#                        L4_category
# 0                        Pot Racks
# 1                  Protective Gear
# 2                    Baseball Bats
# 3                               na
# 4                       Card Stock
# ...                            ...
# 443494                          na
# 443495  Decorative Signs & Plaques
# 443496                   Drinkware
# 443497            Player Equipment
# 443498                          na
#
# [443499 rows x 10 columns]

# %%
import pandas as pd
from collections import Counter

# Assuming merged_df is our DataFrame from the previous step

# Function to count unique values and print the top N
def analyze_column(df, column_name, top_n=10):
    value_counts = df[column_name].value_counts()
    total_values = len(value_counts)
    print(f"\n{column_name}:")
    print(f"Total unique values: {total_values}")
    print(f"Top {top_n} most common values:")
    print(value_counts.head(top_n))
    return total_values

# Analyze each category level and brand
num_brands = analyze_column(merged_df, 'details_Brand')
num_l0 = analyze_column(merged_df, 'L0_category')
num_l1 = analyze_column(merged_df, 'L1_category')
num_l2 = analyze_column(merged_df, 'L2_category')
num_l3 = analyze_column(merged_df, 'L3_category')
num_l4 = analyze_column(merged_df, 'L4_category')
# Out:
# details_Brand:
# Total unique values: 5066
# Top 10 most common values:
# details_Brand
# Dorman             4922
# 3dRose             4282
# ACDelco            4140
# Generic            3670
# CafePress          3008
# WinCraft           2419
# GRAPHICS & MORE    2324
# WeatherTech        1965
# Evan Fischer       1959
# Power Stop         1844
# Name: count, dtype: int64
#
# L0_category:
# Total unique values: 27
# Top 10 most common values:
# L0_category
# Automotive                  146024
# Home & Kitchen               67467
# Sports & Outdoors            46917
# Electronics                  43845
# Tools & Home Improvement     36553
# Office Products              28366
# Arts, Crafts & Sewing        18339
# Patio, Lawn & Garden         17328
# Beauty & Personal Care       11606
# Health & Household            8617
# Name: count, dtype: int64
#
# L1_category:
# Total unique values: 163
# Top 10 most common values:
# L1_category
# Replacement Parts           78780
# Home Dcor Products          23083
# Computers & Accessories     21964
# Kitchen & Dining            21700
# Office & School Supplies    20941
# Exterior Accessories        20831
# Sports                      20552
# Motorcycle & Powersports    14669
# Fan Shop                    12418
# Interior Accessories        12054
# Name: count, dtype: int64
#
# L2_category:
# Total unique values: 612
# Top 10 most common values:
# L2_category
# Body & Trim                          16426
# Brake System                         13773
# Shocks, Struts & Suspension          12827
# Home Dcor Accents                    12341
# Dining & Entertaining                11139
# Parts                                11135
# Bumper Stickers, Decals & Magnets     8875
# Lighting Assemblies & Accessories     8615
# Computer Components                   7684
# Accessories                           7678
# Name: count, dtype: int64
#
# L3_category:
# Total unique values: 1252
# Top 10 most common values:
# L3_category
# na                                           41246
# Body                                         12062
# Internal Components                           6932
# Printer Parts & Accessories                   5182
# Decals                                        5009
# Hanging Ornaments                             4526
# Trim                                          4401
# Headlight Assemblies, Parts & Accessories     4356
# Brake Kits                                    3933
# Pens & Refills                                3785
# Name: count, dtype: int64
#
# L4_category:
# Total unique values: 962
# Top 10 most common values:
# L4_category
# na                              226742
# Printer Ink & Toner               5182
# Headlight Assemblies              4356
# Mirrors & Parts                   3840
# Drinkware                         3402
# Interior                          3105
# Tail Light Assemblies             2991
# Lawn Mower Replacement Parts      2739
# Greeting Cards                    2436
# Decorative Signs & Plaques        2435
# Name: count, dtype: int64

# %%
import json
import pandas as pd

def read_json_to_dataframe(file_path):
    # Read the JSON file line by line
    with open(file_path, 'r') as file:
        data = [json.loads(line) for line in file]
    
    # Convert the list of dictionaries to a DataFrame
    df = pd.DataFrame(data)
    
    return df

# Read input data
input_file_path = '/kaggle/input/datathon-indo-ml/attribute_val.data'
input_df = read_json_to_dataframe(input_file_path)

# Read output data
output_file_path = '/kaggle/input/datathon-indo-ml/attribute_val.solution'
output_df = read_json_to_dataframe(output_file_path)

# Display the first few rows of each DataFrame
print("Input DataFrame:")
print(input_df.head())
print("\nOutput DataFrame:")
print(output_df.head())

# Check the number of rows in each DataFrame
print(f"\nNumber of rows in input DataFrame: {len(input_df)}")
print(f"Number of rows in output DataFrame: {len(output_df)}")

# Merge the input and output DataFrames on 'indoml_id'
merged_val_df = pd.merge(input_df, output_df, on='indoml_id', how='inner')

print("\nMerged DataFrame:")
print(merged_val_df.head())
print(f"\nNumber of rows in merged DataFrame: {len(merged_df)}")

# Save the merged DataFrame to a CSV file (optional)
merged_val_df.to_csv('merged_data.csv', index=False)
# Out:
# Input DataFrame:
#    indoml_id                                              title      store  \
# 0          0  Pendleton, Eco-Wise Washable Wool Blanket, Bla...  Pendleton
# 1          1  JP London MD3A049 DM1578 Space Nebula Removabl...  JP London
# 2          2  Lawn Fawn LF2938 Fangtastic Friends - Lawn Cut...  Lawn Fawn
# 3          3  ANCHEER Foldable Elliptical Machine for Home U...    ANCHEER
# 4          4  Schecter Jeff Loomis JLV-7 NT Left Handed 7-St...   Schecter
#
#      details_Manufacturer
# 0  Pendleton Woolen Mills
# 1               JP London
# 2               Lawn Fawn
# 3                 ANCHEER
# 4                     NaN
#
# Output DataFrame:
#    indoml_id details_Brand               L0_category  \
# 0          0     Pendleton            Home & Kitchen
# 1          1     JP London  Tools & Home Improvement
# 2          2     Lawn Fawn     Arts, Crafts & Sewing
# 3          3       ANCHEER         Sports & Outdoors
# 4          4      Schecter       Musical Instruments
#
#                          L1_category              L2_category  \
# 0                            Bedding        Blankets & Throws
# 1  Paint, Wall Treatments & Supplies   Wall Stickers & Murals
# 2            Scrapbooking & Stamping  Die-Cutting & Embossing
# 3                 Exercise & Fitness          Cardio Training
# 4                            Guitars         Electric Guitars
#
#            L3_category L4_category
# 0         Bed Blankets          na
# 1                   na          na
# 2             Die-Cuts          na
# 3  Elliptical Trainers          na
# 4           Solid Body          na
#
# Number of rows in input DataFrame: 95035
# Number of rows in output DataFrame: 95035
#
# Merged DataFrame:
#    indoml_id                                              title      store  \
# 0          0  Pendleton, Eco-Wise Washable Wool Blanket, Bla...  Pendleton
# 1          1  JP London MD3A049 DM1578 Space Nebula Removabl...  JP London
# 2          2  Lawn Fawn LF2938 Fangtastic Friends - Lawn Cut...  Lawn Fawn
# 3          3  ANCHEER Foldable Elliptical Machine for Home U...    ANCHEER
# 4          4  Schecter Jeff Loomis JLV-7 NT Left Handed 7-St...   Schecter
#
#      details_Manufacturer details_Brand               L0_category  \
# 0  Pendleton Woolen Mills     Pendleton            Home & Kitchen
# 1               JP London     JP London  Tools & Home Improvement
# 2               Lawn Fawn     Lawn Fawn     Arts, Crafts & Sewing
# 3                 ANCHEER       ANCHEER         Sports & Outdoors
# 4                     NaN      Schecter       Musical Instruments
#
#                          L1_category              L2_category  \
# 0                            Bedding        Blankets & Throws
# 1  Paint, Wall Treatments & Supplies   Wall Stickers & Murals
# 2            Scrapbooking & Stamping  Die-Cutting & Embossing
# 3                 Exercise & Fitness          Cardio Training
# 4                            Guitars         Electric Guitars
#
#            L3_category L4_category
# 0         Bed Blankets          na
# 1                   na          na
# 2             Die-Cuts          na
# 3  Elliptical Trainers          na
# 4           Solid Body          na
#
# Number of rows in merged DataFrame: 443499

# %%
print(set(merged_df['L0_category'].to_list()) == set(merged_val_df['L0_category'].to_list()))
print(set(merged_df['L1_category'].to_list()) == set(merged_val_df['L1_category'].to_list()))
print(set(merged_df['L2_category'].to_list()) == set(merged_val_df['L2_category'].to_list()))
print(set(merged_df['L3_category'].to_list()) == set(merged_val_df['L3_category'].to_list()))
print(set(merged_df['L4_category'].to_list()) == set(merged_val_df['L4_category'].to_list()))
# Out:
# True
# True
# True
# True
# True

# %%
import torch
import torch.nn as nn
from transformers import RobertaTokenizer, RobertaModel
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, f1_score
from tqdm import tqdm
import pandas as pd
import numpy as np

class HierarchicalProductClassifier(nn.Module):
    def __init__(self, num_categories, embedding_dim=768):
        super(HierarchicalProductClassifier, self).__init__()
        self.roberta = RobertaModel.from_pretrained('distilroberta-base')  # Use a less computationally expensive model
        self.dropout = nn.Dropout(0.1)
        
        self.category_classifiers = nn.ModuleList([
            nn.Linear(embedding_dim, num_categories) for _ in range(5)
        ])

    def forward(self, input_ids, attention_mask):
        roberta_output = self.roberta(input_ids=input_ids, attention_mask=attention_mask)
        pooled_output = roberta_output.pooler_output
        pooled_output = self.dropout(pooled_output)
        
        category_logits = [classifier(pooled_output) for classifier in self.category_classifiers]
        
        return category_logits

# %%
class ProductDataset(torch.utils.data.Dataset):
    def __init__(self, encodings):
        self.input_ids = encodings['input_ids']
        self.attention_mask = encodings['attention_mask']
        self.category_labels = [encodings['category_l0'],encodings['category_l1'],encodings['category_l2'],encodings['category_l3'],encodings['category_l4']]

    def __len__(self):
        return len(self.input_ids)

    def __getitem__(self, idx):
        item = {
            'input_ids': torch.tensor(self.input_ids[idx], dtype=torch.long),
            'attention_mask': torch.tensor(self.attention_mask[idx], dtype=torch.long),
        }
        item.update({f'category_l{i}': torch.tensor(self.category_labels[i][idx], dtype=torch.long) for i in range(5)})
        return item

# %%
def preprocess_data(df, tokenizer, category_encoder):
    texts = df['title'].tolist()
    categories = [df[f'L{i}_category'].tolist() for i in range(5)]

    encodings = tokenizer(texts, truncation=True, padding=True, max_length=128)
    category_ids = [torch.tensor(category_encoder.transform(cats), dtype=torch.long) for cats in categories]

    return {
        'input_ids': torch.tensor(encodings['input_ids'], dtype=torch.long),
        'attention_mask': torch.tensor(encodings['attention_mask'], dtype=torch.long),
        'category_l0': category_ids[0],
        'category_l1': category_ids[1],
        'category_l2': category_ids[2],
        'category_l3': category_ids[3],
        'category_l4': category_ids[4],
    }

# %%
def compute_metrics(predictions, labels):
    accuracy = accuracy_score(labels, predictions)
    f1 = f1_score(labels, predictions, average='weighted')
    return accuracy, f1

def evaluate(model, dataloader, device, category_encoder):
    model.eval()
    all_predictions = {f'category_l{i}': [] for i in range(5)}
    all_labels = {f'category_l{i}': [] for i in range(5)}
    
    with torch.no_grad():
        for batch in tqdm(dataloader, desc="Evaluating"):
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            
            category_logits = model(input_ids, attention_mask)
            
            for i, logits in enumerate(category_logits):
                all_predictions[f'category_l{i}'].extend(torch.argmax(logits, dim=1).cpu().numpy())
                all_labels[f'category_l{i}'].extend(batch[f'category_l{i}'].cpu().numpy())
    
    print("\nEvaluation Metrics:")
    overall_accuracy = 0
    overall_f1 = 0
    for key in all_predictions.keys():
        predictions = category_encoder.inverse_transform(all_predictions[key])
        labels = category_encoder.inverse_transform(all_labels[key])
        
        accuracy, f1 = compute_metrics(predictions, labels)
        print(f"{key.capitalize()}:")
        print(f"  Accuracy: {accuracy:.4f}")
        print(f"  F1 Score: {f1:.4f}")
        overall_accuracy += accuracy
        overall_f1 += f1
    
    num_tasks = len(all_predictions)
    print("\nOverall Metrics:")
    print(f"  Average Accuracy: {overall_accuracy/num_tasks:.4f}")
    print(f"  Average F1 Score: {overall_f1/num_tasks:.4f}")
    
    return overall_accuracy / num_tasks

# %%
from torch.optim.lr_scheduler import ReduceLROnPlateau
import torch.nn.utils as utils
import copy

def train(model, train_dataloader, val_dataloader, optimizer, device, num_epochs, category_encoder, patience=3):
    best_accuracy = 0
    best_model_wts = copy.deepcopy(model.state_dict())
    scheduler = ReduceLROnPlateau(optimizer, mode='max', factor=0.1, patience=2, verbose=True)
    early_stopping_patience = patience
    early_stopping_counter = 0

    for epoch in range(num_epochs):
        model.train()
        total_loss = 0
        for batch in tqdm(train_dataloader, desc=f"Training Epoch {epoch+1}/{num_epochs}"):
            optimizer.zero_grad()
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            category_labels = [batch[f'category_l{i}'].to(device) for i in range(5)]
            category_logits = model(input_ids, attention_mask)
            loss_fct = nn.CrossEntropyLoss()
            loss = sum(loss_fct(logits, labels) for logits, labels in zip(category_logits, category_labels))
            
            loss.backward()

            # Gradient clipping
            utils.clip_grad_norm_(model.parameters(), max_norm=1.0)

            optimizer.step()
            total_loss += loss.item()

        avg_loss = total_loss / len(train_dataloader)
        print(f"Epoch {epoch+1}/{num_epochs}, Average Loss: {avg_loss:.4f}")
        
        print("\nEvaluating on train set...")
        accuracy = evaluate(model, train_dataloader, device, category_encoder)

        print("\nEvaluating on validation set...")
        accuracy = evaluate(model, val_dataloader, device, category_encoder)

        # Scheduler step
        scheduler.step(accuracy)

        if accuracy > best_accuracy:
            best_accuracy = accuracy
            best_model_wts = copy.deepcopy(model.state_dict())
            early_stopping_counter = 0  # Reset the early stopping counter
        else:
            early_stopping_counter += 1

        # Early stopping
        if early_stopping_counter >= early_stopping_patience:
            print(f"Early stopping triggered after {epoch+1} epochs.")
            break

    model.load_state_dict(best_model_wts)  # Load the best model weights
    return best_accuracy

# %%
# Load data
train_df = merged_df
val_df = merged_val_df

# Create label encoders
category_encoder = LabelEncoder()

all_categories = []
for df in [train_df, val_df]:
    for i in range(5):
        all_categories.extend(df[f'L{i}_category'].tolist())

category_encoder.fit(all_categories)

tokenizer = RobertaTokenizer.from_pretrained('distilroberta-base')

train_dataset = ProductDataset(preprocess_data(train_df, tokenizer, category_encoder))
val_dataset = ProductDataset(preprocess_data(val_df, tokenizer, category_encoder))

train_dataloader = torch.utils.data.DataLoader(train_dataset, batch_size=32, shuffle=True)
val_dataloader = torch.utils.data.DataLoader(val_dataset, batch_size=32, shuffle=False)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = HierarchicalProductClassifier(len(category_encoder.classes_)).to(device)

optimizer = torch.optim.AdamW(model.parameters(), lr=2e-5)
num_epochs = 8
print("Starting model training...")
best_accuracy = train(model, train_dataloader, val_dataloader, optimizer, device, num_epochs, category_encoder)

print(f"Training completed. Best validation accuracy: {best_accuracy:.4f}")
# Out:
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/480 [00:00<?, ?B/s]
# /opt/conda/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# model.safetensors:   0%|          | 0.00/331M [00:00<?, ?B/s]
# Starting model training...
# Training Epoch 1/8:   0%|          | 0/13860 [00:00<?, ?it/s]/tmp/ipykernel_23/594898887.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   'input_ids': torch.tensor(self.input_ids[idx], dtype=torch.long),
# /tmp/ipykernel_23/594898887.py:13: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   'attention_mask': torch.tensor(self.attention_mask[idx], dtype=torch.long),
# /tmp/ipykernel_23/594898887.py:15: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item.update({f'category_l{i}': torch.tensor(self.category_labels[i][idx], dtype=torch.long) for i in range(5)})
# Training Epoch 1/8: 100%|██████████| 13860/13860 [44:43<00:00,  5.17it/s]
# Epoch 1/8, Average Loss: 7.9103
#
# Evaluating on train set...
# Evaluating: 100%|██████████| 13860/13860 [14:01<00:00, 16.47it/s]
# Evaluation Metrics:
# Category_l0:
#   Accuracy: 0.9692
#   F1 Score: 0.9685
# Category_l1:
#   Accuracy: 0.9353
#   F1 Score: 0.9281
# Category_l2:
#   Accuracy: 0.8702
#   F1 Score: 0.8460
# Category_l3:
#   Accuracy: 0.7710
#   F1 Score: 0.7177
# Category_l4:
#   Accuracy: 0.8242
#   F1 Score: 0.7827
#
# Overall Metrics:
#   Average Accuracy: 0.8740
#   Average F1 Score: 0.8486
#
# Evaluating on validation set...
# Evaluating:   0%|          | 0/2970 [00:00<?, ?it/s]/tmp/ipykernel_23/594898887.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   'input_ids': torch.tensor(self.input_ids[idx], dtype=torch.long),
# /tmp/ipykernel_23/594898887.py:13: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   'attention_mask': torch.tensor(self.attention_mask[idx], dtype=torch.long),
# /tmp/ipykernel_23/594898887.py:15: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item.update({f'category_l{i}': torch.tensor(self.category_labels[i][idx], dtype=torch.long) for i in range(5)})
# Evaluating: 100%|██████████| 2970/2970 [03:00<00:00, 16.43it/s]
# Evaluation Metrics:
# Category_l0:
#   Accuracy: 0.9638
#   F1 Score: 0.9631
# Category_l1:
#   Accuracy: 0.9281
#   F1 Score: 0.9208
# Category_l2:
#   Accuracy: 0.8627
#   F1 Score: 0.8383
# Category_l3:
#   Accuracy: 0.7637
#   F1 Score: 0.7101
# Category_l4:
#   Accuracy: 0.8186
#   F1 Score: 0.7764
#
# Overall Metrics:
#   Average Accuracy: 0.8674
#   Average F1 Score: 0.8417
# Training Epoch 2/8:   0%|          | 0/13860 [00:00<?, ?it/s]/tmp/ipykernel_23/594898887.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   'input_ids': torch.tensor(self.input_ids[idx], dtype=torch.long),
# /tmp/ipykernel_23/594898887.py:13: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   'attention_mask': torch.tensor(self.attention_mask[idx], dtype=torch.long),
# /tmp/ipykernel_23/594898887.py:15: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item.update({f'category_l{i}': torch.tensor(self.category_labels[i][idx], dtype=torch.long) for i in range(5)})
# Training Epoch 2/8: 100%|██████████| 13860/13860 [44:45<00:00,  5.16it/s]
# Epoch 2/8, Average Loss: 2.2406
#
# Evaluating on train set...
# Evaluating: 100%|██████████| 13860/13860 [14:06<00:00, 16.37it/s]
# Evaluation Metrics:
# Category_l0:
#   Accuracy: 0.9845
#   F1 Score: 0.9843
# Category_l1:
#   Accuracy: 0.9671
#   F1 Score: 0.9654
# Category_l2:
#   Accuracy: 0.9415
#   F1 Score: 0.9344
# Category_l3:
#   Accuracy: 0.8904
#   F1 Score: 0.8714
# Category_l4:
#   Accuracy: 0.9145
#   F1 Score: 0.8983
#
# Overall Metrics:
#   Average Accuracy: 0.9396
#   Average F1 Score: 0.9307
#
# Evaluating on validation set...
# Evaluating:   0%|          | 0/2970 [00:00<?, ?it/s]/tmp/ipykernel_23/594898887.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   'input_ids': torch.tensor(self.input_ids[idx], dtype=torch.long),
# /tmp/ipykernel_23/594898887.py:13: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   'attention_mask': torch.tensor(self.attention_mask[idx], dtype=torch.long),
# /tmp/ipykernel_23/594898887.py:15: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item.update({f'category_l{i}': torch.tensor(self.category_labels[i][idx], dtype=torch.long) for i in range(5)})
# Evaluating: 100%|██████████| 2970/2970 [03:01<00:00, 16.39it/s]
# Evaluation Metrics:
# Category_l0:
#   Accuracy: 0.9778
#   F1 Score: 0.9777
# Category_l1:
#   Accuracy: 0.9577
#   F1 Score: 0.9560
# Category_l2:
#   Accuracy: 0.9299
#   F1 Score: 0.9225
# Category_l3:
#   Accuracy: 0.8789
#   F1 Score: 0.8595
# Category_l4:
#   Accuracy: 0.9056
#   F1 Score: 0.8891
#
# Overall Metrics:
#   Average Accuracy: 0.9300
#   Average F1 Score: 0.9210
# Training Epoch 3/8:   0%|          | 0/13860 [00:00<?, ?it/s]/tmp/ipykernel_23/594898887.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   'input_ids': torch.tensor(self.input_ids[idx], dtype=torch.long),
# /tmp/ipykernel_23/594898887.py:13: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   'attention_mask': torch.tensor(self.attention_mask[idx], dtype=torch.long),
# /tmp/ipykernel_23/594898887.py:15: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item.update({f'category_l{i}': torch.tensor(self.category_labels[i][idx], dtype=torch.long) for i in range(5)})
# Training Epoch 3/8: 100%|██████████| 13860/13860 [44:44<00:00,  5.16it/s]
# Epoch 3/8, Average Loss: 1.2309
#
# Evaluating on train set...
# Evaluating: 100%|██████████| 13860/13860 [14:07<00:00, 16.36it/s]
# Evaluation Metrics:
# Category_l0:
#   Accuracy: 0.9882
#   F1 Score: 0.9881
# Category_l1:
#   Accuracy: 0.9756
#   F1 Score: 0.9747
# Category_l2:
#   Accuracy: 0.9626
#   F1 Score: 0.9601
# Category_l3:
#   Accuracy: 0.9312
#   F1 Score: 0.9240
# Category_l4:
#   Accuracy: 0.9453
#   F1 Score: 0.9390
#
# Overall Metrics:
#   Average Accuracy: 0.9606
#   Average F1 Score: 0.9572
#
# Evaluating on validation set...
# Evaluating:   0%|          | 0/2970 [00:00<?, ?it/s]/tmp/ipykernel_23/594898887.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   'input_ids': torch.tensor(self.input_ids[idx], dtype=torch.long),
# /tmp/ipykernel_23/594898887.py:13: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   'attention_mask': torch.tensor(self.attention_mask[idx], dtype=torch.long),
# /tmp/ipykernel_23/594898887.py:15: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item.update({f'category_l{i}': torch.tensor(self.category_labels[i][idx], dtype=torch.long) for i in range(5)})
# Evaluating: 100%|██████████| 2970/2970 [03:01<00:00, 16.39it/s]
# Evaluation Metrics:
# Category_l0:
#   Accuracy: 0.9806
#   F1 Score: 0.9806
# Category_l1:
#   Accuracy: 0.9643
#   F1 Score: 0.9634
# Category_l2:
#   Accuracy: 0.9485
#   F1 Score: 0.9457
# Category_l3:
#   Accuracy: 0.9162
#   F1 Score: 0.9086
# Category_l4:
#   Accuracy: 0.9337
#   F1 Score: 0.9271
#
# Overall Metrics:
#   Average Accuracy: 0.9487
#   Average F1 Score: 0.9451
# Training Epoch 4/8:   0%|          | 0/13860 [00:00<?, ?it/s]/tmp/ipykernel_23/594898887.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   'input_ids': torch.tensor(self.input_ids[idx], dtype=torch.long),
# /tmp/ipykernel_23/594898887.py:13: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   'attention_mask': torch.tensor(self.attention_mask[idx], dtype=torch.long),
# /tmp/ipykernel_23/594898887.py:15: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item.update({f'category_l{i}': torch.tensor(self.category_labels[i][idx], dtype=torch.long) for i in range(5)})
# Training Epoch 4/8: 100%|██████████| 13860/13860 [44:45<00:00,  5.16it/s]
# Epoch 4/8, Average Loss: 0.8316
#
# Evaluating on train set...
# Evaluating: 100%|██████████| 13860/13860 [14:05<00:00, 16.39it/s]
# Evaluation Metrics:
# Category_l0:
#   Accuracy: 0.9907
#   F1 Score: 0.9908
# Category_l1:
#   Accuracy: 0.9816
#   F1 Score: 0.9815
# Category_l2:
#   Accuracy: 0.9720
#   F1 Score: 0.9707
# Category_l3:
#   Accuracy: 0.9487
#   F1 Score: 0.9448
# Category_l4:
#   Accuracy: 0.9621
#   F1 Score: 0.9595
#
# Overall Metrics:
#   Average Accuracy: 0.9710
#   Average F1 Score: 0.9694
#
# Evaluating on validation set...
# Evaluating:   0%|          | 0/2970 [00:00<?, ?it/s]/tmp/ipykernel_23/594898887.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   'input_ids': torch.tensor(self.input_ids[idx], dtype=torch.long),
# /tmp/ipykernel_23/594898887.py:13: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   'attention_mask': torch.tensor(self.attention_mask[idx], dtype=torch.long),
# /tmp/ipykernel_23/594898887.py:15: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item.update({f'category_l{i}': torch.tensor(self.category_labels[i][idx], dtype=torch.long) for i in range(5)})
# Evaluating: 100%|██████████| 2970/2970 [03:01<00:00, 16.41it/s]
# Evaluation Metrics:
# Category_l0:
#   Accuracy: 0.9829
#   F1 Score: 0.9830
# Category_l1:
#   Accuracy: 0.9690
#   F1 Score: 0.9689
# Category_l2:
#   Accuracy: 0.9570
#   F1 Score: 0.9553
# Category_l3:
#   Accuracy: 0.9313
#   F1 Score: 0.9268
# Category_l4:
#   Accuracy: 0.9491
#   F1 Score: 0.9460
#
# Overall Metrics:
#   Average Accuracy: 0.9579
#   Average F1 Score: 0.9560
# Training Epoch 5/8:   0%|          | 0/13860 [00:00<?, ?it/s]/tmp/ipykernel_23/594898887.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   'input_ids': torch.tensor(self.input_ids[idx], dtype=torch.long),
# /tmp/ipykernel_23/594898887.py:13: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   'attention_mask': torch.tensor(self.attention_mask[idx], dtype=torch.long),
# /tmp/ipykernel_23/594898887.py:15: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item.update({f'category_l{i}': torch.tensor(self.category_labels[i][idx], dtype=torch.long) for i in range(5)})
# Training Epoch 5/8: 100%|██████████| 13860/13860 [44:46<00:00,  5.16it/s]
# Epoch 5/8, Average Loss: 0.6292
#
# Evaluating on train set...
# Evaluating: 100%|██████████| 13860/13860 [14:05<00:00, 16.39it/s]
# Evaluation Metrics:
# Category_l0:
#   Accuracy: 0.9928
#   F1 Score: 0.9928
# Category_l1:
#   Accuracy: 0.9843
#   F1 Score: 0.9836
# Category_l2:
#   Accuracy: 0.9772
#   F1 Score: 0.9760
# Category_l3:
#   Accuracy: 0.9593
#   F1 Score: 0.9573
# Category_l4:
#   Accuracy: 0.9706
#   F1 Score: 0.9691
#
# Overall Metrics:
#   Average Accuracy: 0.9768
#   Average F1 Score: 0.9758
#
# Evaluating on validation set...
# Evaluating:   0%|          | 0/2970 [00:00<?, ?it/s]/tmp/ipykernel_23/594898887.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   'input_ids': torch.tensor(self.input_ids[idx], dtype=torch.long),
# /tmp/ipykernel_23/594898887.py:13: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   'attention_mask': torch.tensor(self.attention_mask[idx], dtype=torch.long),
# /tmp/ipykernel_23/594898887.py:15: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item.update({f'category_l{i}': torch.tensor(self.category_labels[i][idx], dtype=torch.long) for i in range(5)})
# Evaluating: 100%|██████████| 2970/2970 [03:01<00:00, 16.40it/s]
# Evaluation Metrics:
# Category_l0:
#   Accuracy: 0.9843
#   F1 Score: 0.9842
# Category_l1:
#   Accuracy: 0.9713
#   F1 Score: 0.9706
# Category_l2:
#   Accuracy: 0.9608
#   F1 Score: 0.9593
# Category_l3:
#   Accuracy: 0.9395
#   F1 Score: 0.9369
# Category_l4:
#   Accuracy: 0.9561
#   F1 Score: 0.9543
#
# Overall Metrics:
#   Average Accuracy: 0.9624
#   Average F1 Score: 0.9610
# Training Epoch 6/8:   0%|          | 0/13860 [00:00<?, ?it/s]/tmp/ipykernel_23/594898887.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   'input_ids': torch.tensor(self.input_ids[idx], dtype=torch.long),
# /tmp/ipykernel_23/594898887.py:13: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   'attention_mask': torch.tensor(self.attention_mask[idx], dtype=torch.long),
# /tmp/ipykernel_23/594898887.py:15: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item.update({f'category_l{i}': torch.tensor(self.category_labels[i][idx], dtype=torch.long) for i in range(5)})
# Training Epoch 6/8: 100%|██████████| 13860/13860 [44:45<00:00,  5.16it/s]
# Epoch 6/8, Average Loss: 0.5116
#
# Evaluating on train set...
# Evaluating: 100%|██████████| 13860/13860 [14:05<00:00, 16.38it/s]
# Evaluation Metrics:
# Category_l0:
#   Accuracy: 0.9932
#   F1 Score: 0.9932
# Category_l1:
#   Accuracy: 0.9859
#   F1 Score: 0.9860
# Category_l2:
#   Accuracy: 0.9793
#   F1 Score: 0.9791
# Category_l3:
#   Accuracy: 0.9640
#   F1 Score: 0.9629
# Category_l4:
#   Accuracy: 0.9747
#   F1 Score: 0.9736
#
# Overall Metrics:
#   Average Accuracy: 0.9794
#   Average F1 Score: 0.9790
#
# Evaluating on validation set...
# Evaluating:   0%|          | 0/2970 [00:00<?, ?it/s]/tmp/ipykernel_23/594898887.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   'input_ids': torch.tensor(self.input_ids[idx], dtype=torch.long),
# /tmp/ipykernel_23/594898887.py:13: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   'attention_mask': torch.tensor(self.attention_mask[idx], dtype=torch.long),
# /tmp/ipykernel_23/594898887.py:15: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item.update({f'category_l{i}': torch.tensor(self.category_labels[i][idx], dtype=torch.long) for i in range(5)})
# Evaluating: 100%|██████████| 2970/2970 [03:01<00:00, 16.40it/s]
# Evaluation Metrics:
# Category_l0:
#   Accuracy: 0.9836
#   F1 Score: 0.9836
# Category_l1:
#   Accuracy: 0.9708
#   F1 Score: 0.9708
# Category_l2:
#   Accuracy: 0.9605
#   F1 Score: 0.9599
# Category_l3:
#   Accuracy: 0.9409
#   F1 Score: 0.9394
# Category_l4:
#   Accuracy: 0.9582
#   F1 Score: 0.9568
#
# Overall Metrics:
#   Average Accuracy: 0.9628
#   Average F1 Score: 0.9621
# Training Epoch 7/8:   0%|          | 0/13860 [00:00<?, ?it/s]/tmp/ipykernel_23/594898887.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   'input_ids': torch.tensor(self.input_ids[idx], dtype=torch.long),
# /tmp/ipykernel_23/594898887.py:13: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   'attention_mask': torch.tensor(self.attention_mask[idx], dtype=torch.long),
# /tmp/ipykernel_23/594898887.py:15: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item.update({f'category_l{i}': torch.tensor(self.category_labels[i][idx], dtype=torch.long) for i in range(5)})
# Training Epoch 7/8: 100%|██████████| 13860/13860 [44:48<00:00,  5.16it/s]
# Epoch 7/8, Average Loss: 0.4321
#
# Evaluating on train set...
# Evaluating: 100%|██████████| 13860/13860 [14:10<00:00, 16.30it/s]
# Evaluation Metrics:
# Category_l0:
#   Accuracy: 0.9943
#   F1 Score: 0.9943
# Category_l1:
#   Accuracy: 0.9881
#   F1 Score: 0.9880
# Category_l2:
#   Accuracy: 0.9826
#   F1 Score: 0.9819
# Category_l3:
#   Accuracy: 0.9690
#   F1 Score: 0.9680
# Category_l4:
#   Accuracy: 0.9780
#   F1 Score: 0.9774
#
# Overall Metrics:
#   Average Accuracy: 0.9824
#   Average F1 Score: 0.9819
#
# Evaluating on validation set...
# Evaluating:   0%|          | 0/2970 [00:00<?, ?it/s]/tmp/ipykernel_23/594898887.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   'input_ids': torch.tensor(self.input_ids[idx], dtype=torch.long),
# /tmp/ipykernel_23/594898887.py:13: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   'attention_mask': torch.tensor(self.attention_mask[idx], dtype=torch.long),
# /tmp/ipykernel_23/594898887.py:15: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item.update({f'category_l{i}': torch.tensor(self.category_labels[i][idx], dtype=torch.long) for i in range(5)})
# Evaluating: 100%|██████████| 2970/2970 [03:01<00:00, 16.32it/s]
# Evaluation Metrics:
# Category_l0:
#   Accuracy: 0.9844
#   F1 Score: 0.9844
# Category_l1:
#   Accuracy: 0.9729
#   F1 Score: 0.9727
# Category_l2:
#   Accuracy: 0.9631
#   F1 Score: 0.9620
# Category_l3:
#   Accuracy: 0.9440
#   F1 Score: 0.9425
# Category_l4:
#   Accuracy: 0.9600
#   F1 Score: 0.9593
#
# Overall Metrics:
#   Average Accuracy: 0.9649
#   Average F1 Score: 0.9642
# Training Epoch 8/8:   0%|          | 0/13860 [00:00<?, ?it/s]/tmp/ipykernel_23/594898887.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   'input_ids': torch.tensor(self.input_ids[idx], dtype=torch.long),
# /tmp/ipykernel_23/594898887.py:13: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   'attention_mask': torch.tensor(self.attention_mask[idx], dtype=torch.long),
# /tmp/ipykernel_23/594898887.py:15: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item.update({f'category_l{i}': torch.tensor(self.category_labels[i][idx], dtype=torch.long) for i in range(5)})
# Training Epoch 8/8: 100%|██████████| 13860/13860 [44:48<00:00,  5.15it/s]
# Epoch 8/8, Average Loss: 0.3764
#
# Evaluating on train set...
# Evaluating: 100%|██████████| 13860/13860 [14:06<00:00, 16.37it/s]
# Evaluation Metrics:
# Category_l0:
#   Accuracy: 0.9955
#   F1 Score: 0.9955
# Category_l1:
#   Accuracy: 0.9898
#   F1 Score: 0.9897
# Category_l2:
#   Accuracy: 0.9851
#   F1 Score: 0.9846
# Category_l3:
#   Accuracy: 0.9733
#   F1 Score: 0.9728
# Category_l4:
#   Accuracy: 0.9812
#   F1 Score: 0.9810
#
# Overall Metrics:
#   Average Accuracy: 0.9850
#   Average F1 Score: 0.9847
#
# Evaluating on validation set...
# Evaluating:   0%|          | 0/2970 [00:00<?, ?it/s]/tmp/ipykernel_23/594898887.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   'input_ids': torch.tensor(self.input_ids[idx], dtype=torch.long),
# /tmp/ipykernel_23/594898887.py:13: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   'attention_mask': torch.tensor(self.attention_mask[idx], dtype=torch.long),
# /tmp/ipykernel_23/594898887.py:15: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item.update({f'category_l{i}': torch.tensor(self.category_labels[i][idx], dtype=torch.long) for i in range(5)})
# Evaluating: 100%|██████████| 2970/2970 [03:01<00:00, 16.39it/s]
# Evaluation Metrics:
# Category_l0:
#   Accuracy: 0.9847
#   F1 Score: 0.9846
# Category_l1:
#   Accuracy: 0.9734
#   F1 Score: 0.9733
# Category_l2:
#   Accuracy: 0.9641
#   F1 Score: 0.9633
# Category_l3:
#   Accuracy: 0.9460
#   F1 Score: 0.9449
# Category_l4:
#   Accuracy: 0.9617
#   F1 Score: 0.9613
#
# Overall Metrics:
#   Average Accuracy: 0.9660
#   Average F1 Score: 0.9655
# Training completed. Best validation accuracy: 0.9660

# %% [markdown]
# Here below there is a new approach used added early stopping reduce lr on pleateu and embeddings for store_name and manufracturer name

# %%
import json
import pandas as pd

def read_json_to_dataframe(file_path):
    # Read the JSON file line by line
    with open(file_path, 'r') as file:
        data = [json.loads(line) for line in file]
    
    # Convert the list of dictionaries to a DataFrame
    df = pd.DataFrame(data)
    
    return df

# Read input data
input_file_path = '/kaggle/input/datathon-indo-ml/attribute_test.data'
test_df = read_json_to_dataframe(input_file_path)

# %%
def preprocess_test_data(df, tokenizer):
    texts = df['title'].tolist()
    
    encodings = tokenizer(texts, truncation=True, padding=True, max_length=128)
    
    return {
        'input_ids': torch.tensor(encodings['input_ids'], dtype=torch.long),
        'attention_mask': torch.tensor(encodings['attention_mask'], dtype=torch.long)
    }

class ProductTestDataset(torch.utils.data.Dataset):
    def __init__(self, encodings):
        self.input_ids = encodings['input_ids']
        self.attention_mask = encodings['attention_mask']

    def __len__(self):
        return len(self.input_ids)

    def __getitem__(self, idx):
        return {
            'input_ids': torch.tensor(self.input_ids[idx], dtype=torch.long),
            'attention_mask': torch.tensor(self.attention_mask[idx], dtype=torch.long),
        }


# 2. Preprocess the test data
test_encodings = preprocess_test_data(test_df, tokenizer)
test_dataset = ProductTestDataset(test_encodings)
test_dataloader = torch.utils.data.DataLoader(test_dataset, batch_size=32, shuffle=False)

# 3. Make predictions
model.eval()
all_predictions = {f'category_l{i}': [] for i in range(5)}

with torch.no_grad():
    for batch in tqdm(test_dataloader, desc="Predicting"):
        input_ids = batch['input_ids'].to(device)
        attention_mask = batch['attention_mask'].to(device)

        category_logits = model(input_ids, attention_mask)

        for i, logits in enumerate(category_logits):
            all_predictions[f'category_l{i}'].extend(torch.argmax(logits, dim=1).cpu().numpy())

# 4. Decode predictions
decoded_predictions = {f'L{i}_category': category_encoder.inverse_transform(all_predictions[f'category_l{i}']) for i in range(5)}

# 5. Save predictions to CSV
output_df = pd.DataFrame(decoded_predictions)
# Out:
# Predicting:   0%|          | 0/2970 [00:00<?, ?it/s]/tmp/ipykernel_23/2651261266.py:21: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   'input_ids': torch.tensor(self.input_ids[idx], dtype=torch.long),
# /tmp/ipykernel_23/2651261266.py:22: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   'attention_mask': torch.tensor(self.attention_mask[idx], dtype=torch.long),
# Predicting: 100%|██████████| 2970/2970 [02:54<00:00, 17.06it/s]

# %%
output_df['id'] = test_df['indoml_id']
output_df.to_csv('predictions.csv', index=False)
print("Predictions saved to predictions.csv")
# Out:
# Predictions saved to predictions.csv

# %%
# import torch
# import torch.nn as nn
# from transformers import RobertaTokenizer, RobertaModel, get_linear_schedule_with_warmup
# from sklearn.preprocessing import LabelEncoder
# from sklearn.metrics import accuracy_score, f1_score
# from tqdm import tqdm
# import pandas as pd
# import numpy as np
# # import nlpaug.augmenter.word as naw

# class HierarchicalProductClassifier(nn.Module):
#     def __init__(self, num_categories, num_stores, num_manufacturers, embedding_dim=768):
#         super(HierarchicalProductClassifier, self).__init__()
#         self.roberta = RobertaModel.from_pretrained('distilroberta-base')
#         self.dropout = nn.Dropout(0.1)
#         self.store_embedding = nn.Embedding(num_stores, embedding_dim)
#         self.manufacturer_embedding = nn.Embedding(num_manufacturers, embedding_dim)
        
#         self.category_classifiers = nn.ModuleList([
#             nn.Linear(embedding_dim * 3, num_categories) for _ in range(5)
#         ])

#     def forward(self, input_ids, attention_mask, store_ids, manufacturer_ids):
#         roberta_output = self.roberta(input_ids=input_ids, attention_mask=attention_mask)
#         pooled_output = roberta_output.pooler_output
#         pooled_output = self.dropout(pooled_output)
        
#         store_emb = self.store_embedding(store_ids)
#         manufacturer_emb = self.manufacturer_embedding(manufacturer_ids)
        
#         combined = torch.cat((pooled_output, store_emb, manufacturer_emb), dim=1)
        
#         category_logits = [classifier(combined) for classifier in self.category_classifiers]
        
#         return category_logits

# class ProductDataset(torch.utils.data.Dataset):
#     def __init__(self, encodings):
#         self.input_ids = encodings['input_ids']
#         self.attention_mask = encodings['attention_mask']
#         self.store_ids = encodings['store_ids']
#         self.manufacturer_ids = encodings['manufacturer_ids']
#         self.category_labels = [encodings[f'category_l{i}'] for i in range(5)]

#     def __len__(self):
#         return len(self.input_ids)

#     def __getitem__(self, idx):
#         item = {
#             'input_ids': torch.tensor(self.input_ids[idx], dtype=torch.long),
#             'attention_mask': torch.tensor(self.attention_mask[idx], dtype=torch.long),
#             'store_ids': torch.tensor(self.store_ids[idx], dtype=torch.long),
#             'manufacturer_ids': torch.tensor(self.manufacturer_ids[idx], dtype=torch.long),
#         }
#         item.update({f'category_l{i}': torch.tensor(self.category_labels[i][idx], dtype=torch.long) for i in range(5)})
#         return item

# def preprocess_data(df, tokenizer, category_encoder, store_encoder, manufacturer_encoder, aug=None):
#     texts = df['title'].tolist()
#     if aug:
#         texts = [aug.augment(text)[0] for text in texts]
#     stores = df['store'].tolist()
#     manufacturers = df['details_Manufacturer'].tolist()
#     categories = [df[f'L{i}_category'].tolist() for i in range(5)]

#     encodings = tokenizer(texts, truncation=True, padding=True, max_length=128)
#     store_ids = store_encoder.transform(stores)
#     manufacturer_ids = manufacturer_encoder.transform(manufacturers)
#     category_ids = [category_encoder.transform(cats) for cats in categories]

#     return {
#         'input_ids': encodings['input_ids'],
#         'attention_mask': encodings['attention_mask'],
#         'store_ids': store_ids,
#         'manufacturer_ids': manufacturer_ids,
#         'category_l0': category_ids[0],
#         'category_l1': category_ids[1],
#         'category_l2': category_ids[2],
#         'category_l3': category_ids[3],
#         'category_l4': category_ids[4],
#     }

# def compute_metrics(predictions, labels):
#     accuracy = accuracy_score(labels, predictions)
#     f1 = f1_score(labels, predictions, average='weighted')
#     return accuracy, f1

# def evaluate(model, dataloader, device, category_encoder):
#     model.eval()
#     all_predictions = {f'category_l{i}': [] for i in range(5)}
#     all_labels = {f'category_l{i}': [] for i in range(5)}
    
#     with torch.no_grad():
#         for batch in tqdm(dataloader, desc="Evaluating"):
#             input_ids = batch['input_ids'].to(device)
#             attention_mask = batch['attention_mask'].to(device)
#             store_ids = batch['store_ids'].to(device)
#             manufacturer_ids = batch['manufacturer_ids'].to(device)
            
#             category_logits = model(input_ids, attention_mask, store_ids, manufacturer_ids)
            
#             for i, logits in enumerate(category_logits):
#                 all_predictions[f'category_l{i}'].extend(torch.argmax(logits, dim=1).cpu().numpy())
#                 all_labels[f'category_l{i}'].extend(batch[f'category_l{i}'].cpu().numpy())
    
#     print("\nEvaluation Metrics:")
#     overall_accuracy = 0
#     overall_f1 = 0
#     for key in all_predictions.keys():
#         predictions = category_encoder.inverse_transform(all_predictions[key])
#         labels = category_encoder.inverse_transform(all_labels[key])
        
#         accuracy, f1 = compute_metrics(predictions, labels)
#         print(f"{key.capitalize()}:")
#         print(f"  Accuracy: {accuracy:.4f}")
#         print(f"  F1 Score: {f1:.4f}")
#         overall_accuracy += accuracy
#         overall_f1 += f1
    
#     num_tasks = len(all_predictions)
#     print("\nOverall Metrics:")
#     print(f"  Average Accuracy: {overall_accuracy/num_tasks:.4f}")
#     print(f"  Average F1 Score: {overall_f1/num_tasks:.4f}")
    
#     return overall_accuracy / num_tasks

# def train(model, train_dataloader, val_dataloader, optimizer, scheduler, device, num_epochs, category_encoder):
#     best_accuracy = 0
#     patience = 3
#     no_improve_epochs = 0

#     for epoch in range(num_epochs):
#         model.train()
#         total_loss = 0
#         for batch in tqdm(train_dataloader, desc=f"Training Epoch {epoch+1}/{num_epochs}"):
#             optimizer.zero_grad()
#             input_ids = batch['input_ids'].to(device)
#             attention_mask = batch['attention_mask'].to(device)
#             store_ids = batch['store_ids'].to(device)
#             manufacturer_ids = batch['manufacturer_ids'].to(device)
#             category_labels = [batch[f'category_l{i}'].to(device) for i in range(5)]

#             category_logits = model(input_ids, attention_mask, store_ids, manufacturer_ids)

#             loss_fct = nn.CrossEntropyLoss()
#             loss = sum(loss_fct(logits, labels) for logits, labels in zip(category_logits, category_labels))
#             loss.backward()

#             torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
#             optimizer.step()
#             scheduler.step()

#             total_loss += loss.item()
        
#         avg_loss = total_loss / len(train_dataloader)
#         print(f"Epoch {epoch+1}/{num_epochs}, Average Loss: {avg_loss:.4f}")
#         print("\nEvaluating on train set...")
#         accuracy = evaluate(model, train_dataloader, device, category_encoder)
        
        
#         print("\nEvaluating on validation set...")
#         accuracy = evaluate(model, val_dataloader, device, category_encoder)
        
#         if accuracy > best_accuracy:
#             best_accuracy = accuracy
#             no_improve_epochs = 0
#             torch.save(model.state_dict(), 'best_model.pth')
#         else:
#             no_improve_epochs += 1
        
#         if no_improve_epochs >= patience:
#             print(f"Early stopping triggered after epoch {epoch+1}")
#             break
    
#     return best_accuracy

# # Load data
# train_df = merged_df[:10000]
# val_df = merged_val_df[:10000]

# # Create label encoders
# category_encoder = LabelEncoder()
# store_encoder = LabelEncoder()
# manufacturer_encoder = LabelEncoder()

# all_categories = []
# all_stores = train_df['store'].tolist() + val_df['store'].tolist()
# all_manufacturers = train_df['details_Manufacturer'].tolist() + val_df['details_Manufacturer'].tolist()

# for df in [train_df, val_df]:
#     for i in range(5):
#         all_categories.extend(df[f'L{i}_category'].tolist())

# category_encoder.fit(all_categories)
# store_encoder.fit(all_stores)
# manufacturer_encoder.fit(all_manufacturers)

# tokenizer = RobertaTokenizer.from_pretrained('distilroberta-base')

# # Data augmentation
# # aug = naw.SynonymAug(aug_src='wordnet')

# train_dataset = ProductDataset(preprocess_data(train_df, tokenizer, category_encoder, store_encoder, manufacturer_encoder))
# val_dataset = ProductDataset(preprocess_data(val_df, tokenizer, category_encoder, store_encoder, manufacturer_encoder))

# train_dataloader = torch.utils.data.DataLoader(train_dataset, batch_size=32, shuffle=True)
# val_dataloader = torch.utils.data.DataLoader(val_dataset, batch_size=32, shuffle=False)

# device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# model = HierarchicalProductClassifier(len(category_encoder.classes_), len(store_encoder.classes_), len(manufacturer_encoder.classes_)).to(device)

# optimizer = torch.optim.AdamW(model.parameters(), lr=2e-5)

# num_training_steps = len(train_dataloader) * num_epochs
# scheduler = get_linear_schedule_with_warmup(optimizer, num_warmup_steps=0, num_training_steps=num_training_steps)

# num_epochs = 20
# print("Starting model training...")
# best_accuracy = train(model, train_dataloader, val_dataloader, optimizer, scheduler, device, num_epochs, category_encoder)
# print(f"Training completed. Best validation accuracy: {best_accuracy:.4f}")

# %% [markdown]
# new model has not been able to beat old one despite adding the complexity
